# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import json

# %%
from  folium.plugins import HeatMap
dataset = pd.read_csv("sf18_count_location.csv")

# %%
dataset.count()
# Out:
# Unnamed: 0                 332
# station_name               332
# counts for station_name    332
# lat                        332
# lng                        332
# dtype: int64

# %%
dataset.head()
# Out:
#    Unnamed: 0                                       station_name  \
# 0           0  San Francisco Caltrain Station 2  (Townsend St...
# 1           1  San Francisco Ferry Building (Harry Bridges Pl...
# 2           2     San Francisco Caltrain (Townsend St at 4th St)
# 3           3                      The Embarcadero at Sansome St
# 4           4                               Market St at 10th St
#
#    counts for station_name        lat         lng
# 0                    86598  37.776639 -122.395526
# 1                    82258  37.795392 -122.394203
# 2                    76478  37.776598 -122.395282
# 3                    72114  37.804770 -122.403234
# 4                    69059  37.776619 -122.417385

# %%
data = dataset[['lat', 'lng', 'counts for station_name']].values.tolist()
hmap = folium.Map(location=[37.4700, -122.2500], tiles='stamentoner',
                  control_scale=True, zoom_start=10)
hmap.add_child(HeatMap(data))
file_path = r"test1.html"
hmap.save(file_path)  # save the map as html file

# %% [markdown]
# ## Top 20 and Last 20 station

# %%
location_top=dataset.head(20)
location_top
# Out:
#     Unnamed: 0                                       station_name  \
# 0            0  San Francisco Caltrain Station 2  (Townsend St...
# 1            1  San Francisco Ferry Building (Harry Bridges Pl...
# 2            2     San Francisco Caltrain (Townsend St at 4th St)
# 3            3                      The Embarcadero at Sansome St
# 4            4                               Market St at 10th St
# 5            5   Montgomery St BART Station (Market St at 2nd St)
# 6            6                                 Berry St at 4th St
# 7            7       Powell St BART Station (Market St at 4th St)
# 8            8                            Steuart St at Market St
# 9            9       Powell St BART Station (Market St at 5th St)
# 10          10                              Howard St at Beale St
# 11          11   Embarcadero BART Station (Beale St at Market St)
# 12          12                              3rd St at Townsend St
# 13          13                              Townsend St at 7th St
# 14          14                       4th St at Mission Bay Blvd S
# 15          15  Civic Center/UN Plaza BART Station (Market St ...
# 16          16                            Beale St at Harrison St
# 17          17                              2nd St at Townsend St
# 18          18                           19th Street BART Station
# 19          19                               Post St at Kearny St
#
#     counts for station_name        lat         lng
# 0                     86598  37.776639 -122.395526
# 1                     82258  37.795392 -122.394203
# 2                     76478  37.776598 -122.395282
# 3                     72114  37.804770 -122.403234
# 4                     69059  37.776619 -122.417385
# 5                     67816  37.789625 -122.400811
# 6                     66248  37.775880 -122.393170
# 7                     64428  37.786375 -122.404904
# 8                     56795  37.794130 -122.394430
# 9                     50671  37.783899 -122.408445
# 10                    50331  37.789756 -122.394643
# 11                    41842  37.792251 -122.397086
# 12                    40377  37.778742 -122.392741
# 13                    38549  37.771058 -122.402717
# 14                    37241  37.770407 -122.391198
# 15                    36841  37.781074 -122.411738
# 16                    36109  37.788059 -122.391865
# 17                    35999  37.780526 -122.390288
# 18                    35210  37.809013 -122.268247
# 19                    32269  37.788975 -122.403452

# %%
location_last=dataset.tail(20)
location_last
# Out:
#      Unnamed: 0                           station_name  \
# 312         314                         Tamien Station
# 313         312                       Oak St at 1st St
# 314         313             Farnam St at Fruitvale Ave
# 315         315  W St John St at Guadalupe River Trail
# 316         316                          Guerrero Park
# 317         317              Foothill Blvd at 42nd Ave
# 318         318                   Palm St at Willow St
# 319         319                  Lane St at Revere Ave
# 320         320                   Newhall St at 3rd St
# 321         321         21st Ave at International Blvd
# 322         322                    Empire St at 7th St
# 323         323                          16th St Depot
# 324         324              Mendell St at Fairfax Ave
# 325         325             Laguna St at McAllister St
# 326         326                 Masonic Ave at Turk St
# 327         327                   Willow St at Vine St
# 328         328              Williams Ave at Apollo St
# 329         329                 Williams Ave at 3rd St
# 330         330                    2nd St at S Park St
# 331         331                          Viva Calle SJ
#
#      counts for station_name        lat         lng
# 312                      363  37.312854 -121.882941
# 313                      363  37.322125 -121.881090
# 314                      363  37.777682 -122.225771
# 315                      349  37.335388 -121.897920
# 316                      334  37.745739 -122.422140
# 317                      324  37.775745 -122.213037
# 318                      314  37.317298 -121.884995
# 319                      305  37.731727 -122.390056
# 320                      264  37.738572 -122.389618
# 321                      251  37.785157 -122.238915
# 322                      241  37.347745 -121.890800
# 323                      228  37.766349 -122.396289
# 324                      217  37.739853 -122.385655
# 325                      211  37.779208 -122.426829
# 326                      191  37.779047 -122.447291
# 327                      176  37.318450 -121.883172
# 328                      174  37.730168 -122.398963
# 329                      105  37.729252 -122.392378
# 330                       44  37.782411 -122.392706
# 331                       40  37.263310 -121.833332

# %%
# Instantiate a feature group for the popular stations in the dataframe
pop_stations = folium.map.FeatureGroup()

# Loop through the 10 stations and add each to the stations feature group
for lat, lng, in zip(location_top.lat, location_top.lng):
    pop_stations.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=7, # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            fill_color='red',
            fill_opacity=0.4
        )
    )
    
    
# Instantiate a feature group for the unpopular stations in the dataframe
unpop_stations = folium.map.FeatureGroup()

# Loop through the 10 stations and add each to the stations feature group
for lat, lng, in zip(location_last.lat, location_last.lng):
    pop_stations.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=7, # define how big you want the circle markers to be
            color='blue',
            fill=True,
            fill_color='purple',
            fill_opacity=0.4
        )
    )
# Add incidents to map
chi_map = folium.Map(location=[37.4700, -122.2500])
chi_map.add_child(pop_stations)
chi_map.add_child(unpop_stations)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ced6f88855dfef6b738e6f8fb22498d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ced6f88855dfef6b738e6f8fb22498d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4ced6f88855dfef6b738e6f8fb22498d = L.map(
#                 &quot;map_4ced6f88855dfef6b738e6f8fb22498d&quot;,
#                 {
#                     center: [37.47, -122.25],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4858661c5f0cdf2630811235bfcfe3be = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4ced6f88855dfef6b738e6f8fb22498d);
#
#
#             var feature_group_1cc1f25ebf4c063a7ec9d7b04b94d12d = L.featureGroup(
#                 {}
#             ).addTo(map_4ced6f88855dfef6b738e6f8fb22498d);
#
#
#             var circle_marker_f5c5e41c46a6951e0f778e98b952973f = L.circleMarker(
#                 [37.7766392, -122.3955263],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_1cc1f25ebf4c063a7ec9d7b04b94d12d);
#
#
#             var circle_marker_8a983d0f634873a58d4a2ac40eb00916 = L.circleMarker(
#                 [37.795392, -122.394203],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_1cc1f25ebf4c063a7ec9d7b04b94d12d);
#
#
#             var circle_marker_0bd367409a525f5a5aa1ac3506a75b7e = L.circleMarker(
#                 [37.776598, -122.395282],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_1cc1f25ebf4c063a7ec9d7b04b94d12d);
#
#
#             var circle_marker_ad29e300260088d6f0ddaf1e35ce7acb = L.circleMarker(
#                 [37.80477, -122.403234],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_1cc1f25ebf4c063a7ec9d7b04b94d12d);
#
#
#             var circle_marker_b5ac486288d0036ad4673d8d2e4df070 = L.circleMarker(
#                 [37.776619, -122.417385],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_1cc1f25ebf4c063a7ec9d7b04b94d12d);
#
#
#             var circle_marker_31fcf0d3cc45234075787b4f29b0634d = L.circleMarker(
#                 [37.7896254, -122.400811],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_1cc1f25ebf4c063a7ec9d7b04b94d12d);

# %% [markdown]
# red circles: most popular stations, purple circles: most unpopular stations
