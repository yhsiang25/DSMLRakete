# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import datetime

# %matplotlib inline

# %%
df = pd.read_csv("sf18_weathermerged.csv")

df.head()
# Out:
#    Unnamed: 0    starttime_weather           start_time             end_time  \
# 0           0  2018-01-31 22:00:00  2018-01-31 22:52:36  2018-02-01 19:47:20
# 1           1  2018-01-31 22:00:00  2018-01-31 22:58:45  2018-02-01 00:46:42
# 2           2  2018-01-31 22:00:00  2018-01-31 22:53:42  2018-01-31 23:08:22
# 3           3  2018-01-31 22:00:00  2018-01-31 22:45:38  2018-01-31 23:05:48
# 4           4  2018-01-31 22:00:00  2018-01-31 22:53:28  2018-01-31 23:03:21
#
#    start_station_id  end_station_id          start_station_name  \
# 0               120             285        Mission Dolores Park
# 1               236             160         Market St at 8th St
# 2               123             145        Folsom St at 19th St
# 3               285             133  Webster St at O'Farrell St
# 4               202             195     Washington St at 8th St
#
#              end_station_name  bike_id   user_type  ...      Date_e  \
# ...

# %%
df.drop(['Unnamed: 0'], axis = 1, inplace= True)
df.head()
# Out:
#      starttime_weather           start_time             end_time  \
# 0  2018-01-31 22:00:00  2018-01-31 22:52:36  2018-02-01 19:47:20
# 1  2018-01-31 22:00:00  2018-01-31 22:58:45  2018-02-01 00:46:42
# 2  2018-01-31 22:00:00  2018-01-31 22:53:42  2018-01-31 23:08:22
# 3  2018-01-31 22:00:00  2018-01-31 22:45:38  2018-01-31 23:05:48
# 4  2018-01-31 22:00:00  2018-01-31 22:53:28  2018-01-31 23:03:21
#
#    start_station_id  end_station_id          start_station_name  \
# 0               120             285        Mission Dolores Park
# 1               236             160         Market St at 8th St
# 2               123             145        Folsom St at 19th St
# 3               285             133  Webster St at O'Farrell St
# 4               202             195     Washington St at 8th St
#
#              end_station_name  bike_id   user_type  duration [s]  ...  \
# 0  Webster St at O'Farrell St     2765  Subscriber       75284.0  ...
# ...

# %%
df["starttime_weather"] = pd.to_datetime(df["starttime_weather"], format='%Y-%m-%d %H:%M:%S')
df["month"] = df["starttime_weather"].apply(lambda x: x.month)
df.head()
# Out:
#     starttime_weather           start_time             end_time  \
# 0 2018-01-31 22:00:00  2018-01-31 22:52:36  2018-02-01 19:47:20
# 1 2018-01-31 22:00:00  2018-01-31 22:58:45  2018-02-01 00:46:42
# 2 2018-01-31 22:00:00  2018-01-31 22:53:42  2018-01-31 23:08:22
# 3 2018-01-31 22:00:00  2018-01-31 22:45:38  2018-01-31 23:05:48
# 4 2018-01-31 22:00:00  2018-01-31 22:53:28  2018-01-31 23:03:21
#
#    start_station_id  end_station_id          start_station_name  \
# 0               120             285        Mission Dolores Park
# 1               236             160         Market St at 8th St
# 2               123             145        Folsom St at 19th St
# 3               285             133  Webster St at O'Farrell St
# 4               202             195     Washington St at 8th St
#
#              end_station_name  bike_id   user_type  duration [s]  ...  \
# 0  Webster St at O'Farrell St     2765  Subscriber       75284.0  ...
# ...

# %%
# limit to summer month
df_summer = df[(df["month"] > 5) & (df["month"] < 9)]

# %%
X = df_summer["max_temp"].values.reshape((-1,1)) # if we pass a 1-feature array we need to re-shape it!
y = df_summer["MAX"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MAX'
#
# The above exception was the direct cause of the following exception:
#
# ...
