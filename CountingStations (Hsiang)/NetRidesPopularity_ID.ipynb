# %%
import pandas as pd
import numpy as np

#for working with times objects
from datetime import datetime
from datetime import timedelta

#import csv and check the head of the table
sf18 = pd.read_csv("sf18_cleaned.csv")
sf18.head()
# Out:
#    Unnamed: 0           start_time             end_time  start_station_id  \
# 0           0  2018-01-31 22:52:36  2018-02-01 19:47:20               120
# 1           1  2018-01-31 16:13:35  2018-02-01 15:57:18                15
# 2           2  2018-01-31 14:23:56  2018-02-01 10:16:53               304
# 3           3  2018-01-31 14:53:24  2018-02-01 07:51:21                75
# 4           4  2018-01-31 19:52:25  2018-02-01 06:58:32                74
#
#    end_station_id                                 start_station_name  \
# 0             285                               Mission Dolores Park
# 1              15  San Francisco Ferry Building (Harry Bridges Pl...
# 2             296                               Jackson St at 5th St
# 3              47                           Market St at Franklin St
# 4              19                              Laguna St at Hayes St
#
#                                     end_station_name  bike_id   user_type  \
# 0                         Webster St at O'Farrell St     2765  Subscriber
# 1  San Francisco Ferry Building (Harry Bridges Pl...     2815    Customer
# 2                              5th St at Virginia St     3039    Customer
# 3                              4th St at Harrison St      321    Customer
# 4                               Post St at Kearny St      617  Subscriber
#
#    duration [s]      Date_s  Weekday_s  Hour_s      Date_e  Weekday_e  Hour_e  \
# 0       75284.0  2018-01-31          2      22  2018-02-01          3      19
# 1       85423.0  2018-01-31          2      16  2018-02-01          3      15
# 2       71577.0  2018-01-31          2      14  2018-02-01          3      10
# 3       61077.0  2018-01-31          2      14  2018-02-01          3       7
# 4       39967.0  2018-01-31          2      19  2018-02-01          3       6
#
#    start_station_latitude  start_station_longitude  end_station_latitude  \
# 0               37.761420              -122.426435             37.783521
# 1               37.795392              -122.394203             37.795392
# 2               37.348759              -121.894798             37.325998
# 3               37.773793              -122.421239             37.780955
# 4               37.776435              -122.426244             37.788975
#
#    end_station_longitude
# 0            -122.431158
# 1            -122.394203
# 2            -121.877120
# 3            -122.399749
# 4            -122.403452

# %%
sf18.loc[sf18['start_station_id'] == 120]
# Out:
#          Unnamed: 0           start_time             end_time  \
# 0                 0  2018-01-31 22:52:36  2018-02-01 19:47:20
# 442             442  2018-01-31 19:40:29  2018-01-31 19:55:31
# 2087           2087  2018-01-31 15:17:28  2018-01-31 15:27:56
# 2174           2174  2018-01-31 14:38:31  2018-01-31 14:50:17
# 2242           2242  2018-01-31 14:15:31  2018-01-31 14:20:53
# ...             ...                  ...                  ...
# 1841065     1841065  2018-12-01 14:21:00  2018-12-01 14:34:11
# 1841315     1841315  2018-12-01 12:53:30  2018-12-01 13:21:59
# 1841333     1841333  2018-12-01 13:11:19  2018-12-01 13:15:31
# 1841788     1841788  2018-12-01 10:15:01  2018-12-01 10:33:34
# 1842088     1842088  2018-12-01 01:07:52  2018-12-01 01:20:19
#
#          start_station_id  end_station_id    start_station_name  \
# 0                     120             285  Mission Dolores Park
# 442                   120              41  Mission Dolores Park
# 2087                  120              72  Mission Dolores Park
# 2174                  120              59  Mission Dolores Park
# 2242                  120             105  Mission Dolores Park
# ...                   ...             ...                   ...
# 1841065               120              78  Mission Dolores Park
# 1841315               120             109  Mission Dolores Park
# 1841333               120             122  Mission Dolores Park
# 1841788               120              66  Mission Dolores Park
# 1842088               120              74  Mission Dolores Park
#
#                     end_station_name  bike_id   user_type  duration [s]  \
# 0         Webster St at O'Farrell St     2765  Subscriber       75284.0
# 442       Golden Gate Ave at Polk St      627  Subscriber         902.0
# 2087             Page St at Scott St     2351    Customer         628.0
# 2174     S Van Ness Ave at Market St     3652  Subscriber         706.0
# 2242           16th St at Prosper St     2260  Subscriber         322.0
# ...                              ...      ...         ...           ...
# 1841065          Folsom St at 9th St     1039  Subscriber         791.0
# 1841315       17th St at Valencia St     2526    Customer        1709.0
# 1841333        19th St at Mission St      457  Subscriber         252.0
# 1841788        3rd St at Townsend St      475  Subscriber        1113.0
# 1842088        Laguna St at Hayes St     3447  Subscriber         747.0
#
#              Date_s  Weekday_s  Hour_s      Date_e  Weekday_e  Hour_e  \
# 0        2018-01-31          2      22  2018-02-01          3      19
# 442      2018-01-31          2      19  2018-01-31          2      19
# 2087     2018-01-31          2      15  2018-01-31          2      15
# 2174     2018-01-31          2      14  2018-01-31          2      14
# 2242     2018-01-31          2      14  2018-01-31          2      14
# ...             ...        ...     ...         ...        ...     ...
# 1841065  2018-12-01          5      14  2018-12-01          5      14
# 1841315  2018-12-01          5      12  2018-12-01          5      13
# 1841333  2018-12-01          5      13  2018-12-01          5      13
# 1841788  2018-12-01          5      10  2018-12-01          5      10
# 1842088  2018-12-01          5       1  2018-12-01          5       1
#
#          start_station_latitude  start_station_longitude  \
# 0                      37.76142              -122.426435
# 442                    37.76142              -122.426435
# 2087                   37.76142              -122.426435
# 2174                   37.76142              -122.426435
# 2242                   37.76142              -122.426435
# ...                         ...                      ...
# 1841065                37.76142              -122.426435
# 1841315                37.76142              -122.426435
# 1841333                37.76142              -122.426435
# 1841788                37.76142              -122.426435
# 1842088                37.76142              -122.426435
#
#          end_station_latitude  end_station_longitude
# 0                   37.783521            -122.431158
# 442                 37.781270            -122.418740
# 2087                37.772406            -122.435650
# 2174                37.774814            -122.418954
# 2242                37.764285            -122.431804
# ...                       ...                    ...
# 1841065             37.773717            -122.411647
# 1841315             37.763316            -122.421904
# 1841333             37.760299            -122.418892
# 1841788             37.778742            -122.392741
# 1842088             37.776435            -122.426244
#
# [7803 rows x 20 columns]

# %% [markdown]
# <H2>- count the usage of each stations -</H2>

# %%
#check the frequency of startstations
start_counts = sf18.start_station_id.value_counts().reset_index(name = "start_frequency")
start_counts.columns = ['station_id', 'start_frequency']
start_counts
# Out:
#      station_id  start_frequency
# 0            15            38303
# 1            67            37107
# 2            58            34806
# 3            30            34300
# 4            81            33589
# ..          ...              ...
# 326         301               90
# 327         359               89
# 328         358               50
# 329         374               25
# 330          48               11
#
# [331 rows x 2 columns]

# %%
#check the frequency of endstations
end_counts = sf18.end_station_id.value_counts().reset_index(name = "end_frequency")
end_counts.columns = ['station_id', 'end_frequency']
end_counts
# Out:
#      station_id  end_frequency
# 0            67          49491
# 1            15          43955
# 2            30          42178
# 3             6          38973
# 4            21          35820
# ..          ...            ...
# 326         301             86
# 327         359             85
# 328         358             55
# 329          48             33
# 330         374             15
#
# [331 rows x 2 columns]

# %%
#merge both start and end frequency
mergeStartEnd = pd.merge(start_counts, end_counts, on='station_id',  how='left')
mergeStartEnd
# Out:
#      station_id  start_frequency  end_frequency
# 0            15            38303          43955
# 1            67            37107          49491
# 2            58            34806          34253
# 3            30            34300          42178
# 4            81            33589          32659
# ..          ...              ...            ...
# 326         301               90             86
# 327         359               89             85
# 328         358               50             55
# 329         374               25             15
# 330          48               11             33
#
# [331 rows x 3 columns]

# %%
mergeStartEnd['diff'] = (mergeStartEnd.start_frequency - mergeStartEnd.end_frequency).fillna('-')
mergeStartEnd
# Out:
#      station_id  start_frequency  end_frequency   diff
# 0            15            38303          43955  -5652
# 1            67            37107          49491 -12384
# 2            58            34806          34253    553
# 3            30            34300          42178  -7878
# 4            81            33589          32659    930
# ..          ...              ...            ...    ...
# 326         301               90             86      4
# 327         359               89             85      4
# 328         358               50             55     -5
# 329         374               25             15     10
# 330          48               11             33    -22
#
# [331 rows x 4 columns]

# %% [markdown]
# <H2>- filtering the most popular stations and less popular stations -</H2>

# %%
top_stations = mergeStartEnd.sort_values("diff",ascending = False ,inplace = False).head(10)
top_stations
# Out:
#      station_id  start_frequency  end_frequency  diff
# 21          243            14086           5047  9039
# 101          52             6400           2566  3834
# 111         256             5900           2677  3223
# 48          163            10327           7281  3046
# 133         253             4765           1836  2929
# 110          71             5931           3257  2674
# 23           37            13346          10678  2668
# 9            22            26470          23861  2609
# 29           70            12341           9805  2536
# 95           53             6537           4081  2456

# %%
bottom_stations = mergeStartEnd.sort_values("diff",ascending = True ,inplace = False).head(10)
bottom_stations
# Out:
#     station_id  start_frequency  end_frequency   diff
# 1           67            37107          49491 -12384
# 3           30            34300          42178  -7878
# 5            6            33141          38973  -5832
# 0           15            38303          43955  -5652
# 6           21            31996          35820  -3824
# 65         245             8673          12370  -3697
# 45          36            10846          13571  -2725
# 18         182            16402          18808  -2406
# 13          90            18169          20380  -2211
# 84         350             7520           9382  -1862

# %% [markdown]
# <H2>- merge most and less pupular stations -</H2>

# %%
counts_combine = top_stations.append(bottom_stations).reset_index()
counts_combine
# Out:
# /var/folders/nt/jn6tpqw11vnb154svnj28fw40000gn/T/ipykernel_11880/3558085635.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   counts_combine = top_stations.append(bottom_stations).reset_index()
#     index  station_id  start_frequency  end_frequency   diff
# 0      21         243            14086           5047   9039
# 1     101          52             6400           2566   3834
# 2     111         256             5900           2677   3223
# 3      48         163            10327           7281   3046
# 4     133         253             4765           1836   2929
# 5     110          71             5931           3257   2674
# 6      23          37            13346          10678   2668
# 7       9          22            26470          23861   2609
# 8      29          70            12341           9805   2536
# 9      95          53             6537           4081   2456
# 10      1          67            37107          49491 -12384
# 11      3          30            34300          42178  -7878
# 12      5           6            33141          38973  -5832
# 13      0          15            38303          43955  -5652
# 14      6          21            31996          35820  -3824
# 15     65         245             8673          12370  -3697
# 16     45          36            10846          13571  -2725
# 17     18         182            16402          18808  -2406
# 18     13          90            18169          20380  -2211
# 19     84         350             7520           9382  -1862

# %%
counts_combine.drop('index', axis=1, inplace=True)
counts_combine
# Out:
#     station_id  start_frequency  end_frequency   diff
# 0          243            14086           5047   9039
# 1           52             6400           2566   3834
# 2          256             5900           2677   3223
# 3          163            10327           7281   3046
# 4          253             4765           1836   2929
# 5           71             5931           3257   2674
# 6           37            13346          10678   2668
# 7           22            26470          23861   2609
# 8           70            12341           9805   2536
# 9           53             6537           4081   2456
# 10          67            37107          49491 -12384
# 11          30            34300          42178  -7878
# 12           6            33141          38973  -5832
# 13          15            38303          43955  -5652
# 14          21            31996          35820  -3824
# 15         245             8673          12370  -3697
# 16          36            10846          13571  -2725
# 17         182            16402          18808  -2406
# 18          90            18169          20380  -2211
# 19         350             7520           9382  -1862

# %%
counts_combine.sort_values("diff", ascending = True ,inplace = True)
counts_combine
# Out:
#     station_id  start_frequency  end_frequency   diff
# 10          67            37107          49491 -12384
# 11          30            34300          42178  -7878
# 12           6            33141          38973  -5832
# 13          15            38303          43955  -5652
# 14          21            31996          35820  -3824
# 15         245             8673          12370  -3697
# 16          36            10846          13571  -2725
# 17         182            16402          18808  -2406
# 18          90            18169          20380  -2211
# 19         350             7520           9382  -1862
# 9           53             6537           4081   2456
# 8           70            12341           9805   2536
# 7           22            26470          23861   2609
# 6           37            13346          10678   2668
# 5           71             5931           3257   2674
# 4          253             4765           1836   2929
# 3          163            10327           7281   3046
# 2          256             5900           2677   3223
# 1           52             6400           2566   3834
# 0          243            14086           5047   9039

# %%
# Example python program to plot a horizontal bar chart
# import pandas as pd

import matplotlib.pyplot as plot

popularityChart  = pd.DataFrame(data = counts_combine);

wert = counts_combine['diff']
color = (wert > 0).apply(lambda x: 'g' if x else 'r')

popularityChart.plot.barh(x='station_id', y='diff', color = color, figsize=(10,8), legend=None);
plot.xlabel('Net Rides', size = 10)
plot.ylabel('Stations', size = 10)
plot.title("Net Rides of the most and less popular stations", fontsize = 15)
# counts_combine['diff'].plot(kind='barh', color = counts_combine.positive.map({True: 'g', False: 'r'}))
# plot.legend(loc = 'upper center', bbox_to_anchor = (0.5,-0.1), ncol = 3, fancybox = True, shadow = True)


plot.show(block=True);
