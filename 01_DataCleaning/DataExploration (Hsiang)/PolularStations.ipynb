# %%
#maybe need to be deleted
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import timedelta

popular = pd.read_csv("sf18_weathermerged.csv")
popular.head()
# Out:
#    Unnamed: 0    starttime_weather           start_time             end_time  \
# 0           0  2018-01-31 22:00:00  2018-01-31 22:52:36  2018-02-01 19:47:20
# 1           1  2018-01-31 22:00:00  2018-01-31 22:58:45  2018-02-01 00:46:42
# 2           2  2018-01-31 22:00:00  2018-01-31 22:53:42  2018-01-31 23:08:22
# 3           3  2018-01-31 22:00:00  2018-01-31 22:45:38  2018-01-31 23:05:48
# 4           4  2018-01-31 22:00:00  2018-01-31 22:53:28  2018-01-31 23:03:21
#
#    start_station_id  end_station_id          start_station_name  \
# 0               120             285        Mission Dolores Park
# 1               236             160         Market St at 8th St
# 2               123             145        Folsom St at 19th St
# 3               285             133  Webster St at O'Farrell St
# 4               202             195     Washington St at 8th St
#
#              end_station_name  bike_id   user_type  ...      Date_e  \
# ...

# %%
popular.drop(popular[(popular['start_station_id'] != 243) & (popular['end_station_id'] != 243)
                    & (popular['start_station_id'] != 52) & (popular['end_station_id'] != 52)
                    & (popular['start_station_id'] != 256) & (popular['end_station_id'] != 256)
                    & (popular['start_station_id'] != 163) & (popular['end_station_id'] != 163)
                    & (popular['start_station_id'] != 253) & (popular['end_station_id'] != 253)
                    & (popular['start_station_id'] != 71) & (popular['end_station_id'] != 71)
                    & (popular['start_station_id'] != 37) & (popular['end_station_id'] != 37)
                    & (popular['start_station_id'] != 22) & (popular['end_station_id'] != 22)
                    & (popular['start_station_id'] != 70) & (popular['end_station_id'] != 70)
                     & (popular['start_station_id'] != 53) & (popular['end_station_id'] != 53)
                    ].index, inplace = True)

popular
# Out:
#          Unnamed: 0    starttime_weather           start_time  \
# 51               51  2018-01-31 22:00:00  2018-01-31 22:03:49
# 64               64  2018-01-31 16:00:00  2018-01-31 16:40:50
# 76               76  2018-01-31 16:00:00  2018-01-31 16:50:51
# 90               90  2018-01-31 16:00:00  2018-01-31 16:57:15
# 92               92  2018-01-31 16:00:00  2018-01-31 16:55:03
# ...             ...                  ...                  ...
# 1832969     1832969  2018-12-01 00:00:00  2018-12-01 00:49:35
# 1832983     1832983  2018-12-01 00:00:00  2018-12-01 00:52:30
# 1832984     1832984  2018-12-01 00:00:00  2018-12-01 00:48:32
# 1832985     1832985  2018-12-01 00:00:00  2018-12-01 00:48:28
# 1832988     1832988  2018-12-01 00:00:00  2018-12-01 00:44:25
#
#                     end_time  start_station_id  end_station_id  \
# 51       2018-01-31 22:15:38               109              53
# 64       2018-01-31 17:50:55                43              37
# ...

# %%
popular.to_csv("sf18_weathermerged_populars.csv")
